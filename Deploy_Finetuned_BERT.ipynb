# %% [markdown]
# **Deploy Finetuned transformers (BERT) model**
#
# 1.   Push model to huggingface hub
# 2.   Deploy it on streamlit cloud

# %% [markdown]
# **Why Push model on Huggingface Hub**
#
#
#
# *   Huggingface hub is like github for ML models
# *   Deployment Docker file will be smaller
# *   Updated or Re-trained model will be availabe without redeployement.

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 6.0 MB/s
# ...
#      |████████████████████████████████| 163 kB 34.0 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 32.9 MB/s
# ...

# %%
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# %%
# trainer.save_model('/content/drive/MyDrive/Youtube Tutorials/toxic')
model = BertForSequenceClassification.from_pretrained("/content/drive/MyDrive/30_Days_Interview_prepratipn/NLP_model/toxic")
# model.to('cuda')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
model.push_to_hub("Shivan118/engineeringwalabhaiyaBERT")
# Out:
# CommitInfo(commit_url='https://huggingface.co/Shivan118/engineeringwalabhaiyaBERT/commit/9a6af216052f2b06a7d9abfa0219f4f468cb9845', commit_message='Upload BertForSequenceClassification', commit_description='', oid='9a6af216052f2b06a7d9abfa0219f4f468cb9845', pr_url=None, pr_revision=None, pr_num=None)

# %%
model = BertForSequenceClassification.from_pretrained("Shivan118/engineeringwalabhaiyaBERT")
# Out:
# Downloading:   0%|          | 0.00/777 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
model
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %% [markdown]
# To load your provate Token

# %%
model = BertForSequenceClassification.from_pretrained("Shivan118/engineeringwalabhaiyaBERT",use_auth_token='your auth token')
